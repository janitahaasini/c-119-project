# %% [markdown]
# <a href="https://colab.research.google.com/github/janitahaasini/c-119-project/blob/main/119_decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AIM:**To create our own decision tree algorithm.
#
# lets get started with it

# %% [markdown]
# so, here we have imported **google.colab**for importing the data which is very important

# %%
from google.colab import files
filestoupload=files.upload()
# Out:
#      <input type="file" id="files-241da8c1-c449-4162-aa5f-27194b051b25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-241da8c1-c449-4162-aa5f-27194b051b25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic.csv

# %% [markdown]
# now we have imported the data we need

# %% [markdown]
# now we are  creating the data frames of it.

# %%
import pandas as pd
cNames=['PassengerId','Pclass','Sex,''Age','SibSp','Parch','Survived']
df=pd.read_csv("titanic.csv",names=cNames).iloc[1:]
print(df.head())
# Out:
#   PassengerId Pclass Sex,Age SibSp Parch Survived
# 1           3      1    34.5     1     0        0
# 2           1      0      47     1     0        1
# 3           3      0      62     0     0        1
# 4           1      0      27     1     0        1
# 5           3      1      22     0     0        0

# %%
features=['PassengerId','Pclass','Sex,''Age','SibSp','Parch']
X=df[features]
y=df.Survived

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,random_state=1)
#intializing desicion tree model
clf=DecisionTreeClassifier()
#fitting the data into the model
clf=clf.fit(Xtrain,ytrain)
#calculating the accuracy
y_pred=clf.predict(Xtest)
print("Accuray:",metrics.accuracy_score(ytest,y_pred))
# Out:
# Accuray: 0.7313432835820896

# %% [markdown]
# . Then we split the data to train , test and then fit it into the model.
# and got the accuray

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus
dot_data=StringIO()##where we will store the data from our decision classifer as text
export_graphviz(clf,out_file=dot_data,filled=True,special_characters=True,feature_names=features,class_names=['0','1'])
print(dot_data.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<Pclass &le; 0.5<br/>gini = 0.463<br/>samples = 623<br/>value = [396, 227]<br/>class = 0>, fillcolor="#f4c9aa"] ;
# 1 [label=<PassengerId &le; 2.5<br/>gini = 0.387<br/>samples = 217<br/>value = [57, 160]<br/>class = 1>, fillcolor="#80c0ee"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<Sex,Age &le; 0.5<br/>gini = 0.097<br/>samples = 117<br/>value = [6, 111]<br/>class = 1>, fillcolor="#44a2e6"] ;
# 1 -> 2 ;
# 3 [label=<PassengerId &le; 1.5<br/>gini = 0.391<br/>samples = 15<br/>value = [4, 11]<br/>class = 1>, fillcolor="#81c1ee"] ;
# 2 -> 3 ;
# 4 [label=<Parch &le; 1.0<br/>gini = 0.245<br/>samples = 7<br/>value = [1, 6]<br/>class = 1>, fillcolor="#5aade9"] ;
# 3 -> 4 ;
# 5 [label=<gini = 0.0<br/>samples = 5<br/>value = [0, 5]<br/>class = 1>, fillcolor="#399de5"] ;
# 4 -> 5 ;
# ...

# %% [markdown]
# Using the graph_viz function we created the representation of the data.

# %%
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('Age.png')
Image(graph.create_png())

# %% [markdown]
# Using pydotplus we created the chart image of the data.
